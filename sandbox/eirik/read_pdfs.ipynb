# %%
import boto3

client = boto3.client('textract', region_name='norwegian')

pdf_path = "/home/eirik/projects/planparse/ex_data/200921.pdf"

response = client.detect_document_text(
    Document={
        'S3Object': {
            'Bucket': 'pdf-ocr-files-ploomber',
            'Name': pdf_path,
        }
    }
)

for item in response["Blocks"]:
    # if item["BlockType"] == "LINE":
        #    print (item["Text"])

    print(item)

# %%
import pytesseract
from pdf2image import convert_from_path

pdf_path = "/home/eirik/projects/planparse/ex_data/200921.pdf"

pages = convert_from_path(pdf_path, 600)
text_data = ''
text = pytesseract.image_to_string(pages[1])
text_data += text + '\n'
print(text_data)

# %%
import PyPDF2

pdf_path = "/home/eirik/projects/planparse/ex_data/200921.pdf"

pdfFileObject = open(pdf_path, 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObject)
count = pdfReader.numPages

output = ''
for i in range(count):
    page = pdfReader.getPage(i)
    output += page.extractText()
    # output.append(page.extractText())
    
output
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[7], line 6
#       3 pdf_path = "/home/eirik/projects/planparse/ex_data/200921.pdf"
#       5 pdfFileObject = open(pdf_path, 'rb')
# ----> 6 pdfReader = PyPDF2.PdfFileReader(pdfFileObject)
#       7 count = pdfReader.numPages
#       9 output = ''
#
# File ~/anaconda3/envs/pp/lib/python3.10/site-packages/PyPDF2/_reader.py:1974, in PdfFileReader.__init__(self, *args, **kwargs)
#    1973 def __init__(self, *args: Any, **kwargs: Any) -> None:
# -> 1974     deprecation_with_replacement("PdfFileReader", "PdfReader", "3.0.0")
#    1975     if "strict" not in kwargs and len(args) < 2:
#    1976         kwargs["strict"] = True  # maintain the default
#
# File ~/anaconda3/envs/pp/lib/python3.10/site-packages/PyPDF2/_utils.py:369, in deprecation_with_replacement(old_name, new_name, removed_in)
# ...
